# %%
import boto3
import pandas as pd
import json
from io import StringIO

# %%
# Read data
s3_client = boto3.client('s3')
s3_resource = boto3.resource('s3')

# Talent: combined data
response = s3_client.get_object(Bucket='data-504-final-project', Key='Talent_Combined/combined_talent_decision_scores.csv')
content = response['Body'].read().decode('utf-8')
# print(content)

# %%
# Create a df
df = pd.read_csv(StringIO(content))
df.head(3)
# Out:
#                 name        date                                  strengths  \
# 0  Stillmann Castano  22/08/2019                               ['Charisma']
# 1    Hilary Willmore  01/08/2019  ['Patient', 'Curious', 'Problem Solving']
# 2      Efrem Whipple  22/08/2019    ['Courteous', 'Independent', 'Patient']
#
#                                    weaknesses self_development geo_flex  \
# 0  ['Distracted', 'Impulsive', 'Introverted']              Yes      Yes
# 1    ['Overbearing', 'Chatty', 'Indifferent']               No      Yes
# 2     ['Introverted', 'Impulsive', 'Anxious']              Yes      Yes
#
#   financial_support_self result course_interest  tech_self_score.C#  \
# 0                    Yes   Pass        Business                 6.0
# 1                    Yes   Fail            Data                 4.0
# 2                    Yes   Pass        Business                 NaN
#
#    tech_self_score.Java  tech_self_score.R  tech_self_score.JavaScript  \
# 0                   5.0                2.0                         2.0
# 1                   2.0                NaN                         NaN
# 2                   NaN                NaN                         NaN
#
#    tech_self_score.Python  tech_self_score.C++  tech_self_score.Ruby  \
# 0                     NaN                  NaN                   NaN
# 1                     1.0                  4.0                   NaN
# 2                     NaN                  4.0                   4.0
#
#    tech_self_score.SPSS  tech_self_score.PHP
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN

# %%
# Number of rows
print("Number of rows:")
print(len(df))
print(df.shape)
# Out:
# Number of rows:
# 1000
# (1000, 18)

# %% [markdown]
# ### Missing values

# %%
print(df.isnull().sum())
# Out:
# name                            0
# date                            0
# strengths                       0
# weaknesses                      0
# self_development                0
# geo_flex                        0
# financial_support_self          0
# result                          0
# course_interest                 0
# tech_self_score_CSharp        618
# tech_self_score_Java          609
# tech_self_score_R             651
# tech_self_score_JavaScript    656
# tech_self_score_Python        599
# tech_self_score_C++           642
# tech_self_score_Ruby          633
# tech_self_score_SPSS          665
# tech_self_score_PHP           674
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
# Detect duplicate rows
duplicates = df.duplicated()
print(f"Number of duplicates: {duplicates.sum()}")
# Out:
# Number of duplicates: 11

# %%
# View the duplicate rows
df[duplicates]
# Out:
#                    name        date  \
# 59   Pamelina Itzkovsky  13/08/2019
# 154    Rafi Andrzejczak  07/08/2019
# 211    Redford Bubbings  15/08/2019
# 354           Fee Karpe  17/07/2019
# 466  Mirilla Bottinelli  16/07/2019
# 700        Fidel Norval  19/07/2019
# 776        Gavan Soltan  05/07/2019
# 831         Darn Kirkby  18/07/2019
# 852         Corby Torel  20/07/2019
# 888     Kendell Ruppele  06/07/2019
# 895      Kyla Jankovsky  20/07/2019
#
#                                          strengths  \
# 59      ['Curious', 'Perfectionism', 'Determined']
# 154            ['Critical Thinking', 'Innovative']
# 211           ['Rational', 'Curious', 'Courteous']
# 354                      ['Creative', 'Efficient']
# 466                                   ['Altruism']
# 700                   ['Innovative', 'Determined']
# 776            ['Efficient', 'Empathy', 'Curious']
# 831  ['Competitive', 'Patient', 'Problem Solving']
# 852                                   ['Altruism']
# 888       ['Listening', 'Innovative', 'Composure']
# 895                     ['Determined', 'Rational']
#
#                                     weaknesses self_development geo_flex  \
# 59      ['Impatient', 'Passive', 'Intolerant']              Yes      Yes
# 154     ['Chatty', 'Undisciplined', 'Selfish']              Yes       No
# 211                        ['Procrastination']               No      Yes
# 354       ['Procrastination', 'Perfectionist']              Yes      Yes
# 466                                 ['Chatty']              Yes      Yes
# 700  ['Selfish', 'Controlling', 'Introverted']               No      Yes
# 776                            ['Controlling']              Yes      Yes
# 831                               ['Stubborn']              Yes      Yes
# 852                     ['Indecisive', 'Slow']              Yes      Yes
# 888                 ['Chaotic', 'Introverted']              Yes       No
# 895                                 ['Chatty']              Yes       No
#
#     financial_support_self result course_interest  tech_self_score.C#  \
# 59                     Yes   Pass     Engineering                 NaN
# 154                    Yes   Fail        Business                 NaN
# 211                    Yes   Fail     Engineering                 NaN
# 354                    Yes   Pass            Data                 NaN
# 466                    Yes   Pass            Data                 1.0
# 700                    Yes   Fail     Engineering                 NaN
# 776                     No   Fail     Engineering                 NaN
# 831                    Yes   Pass     Engineering                 3.0
# 852                     No   Fail        Business                 NaN
# 888                    Yes   Fail     Engineering                 NaN
# 895                    Yes   Fail     Engineering                 NaN
#
#      tech_self_score.Java  tech_self_score.R  tech_self_score.JavaScript  \
# 59                    2.0                NaN                         NaN
# 154                   2.0                NaN                         NaN
# 211                   4.0                2.0                         NaN
# 354                   2.0                NaN                         NaN
# 466                   NaN                NaN                         NaN
# 700                   NaN                NaN                         NaN
# 776                   NaN                4.0                         NaN
# 831                   NaN                NaN                         NaN
# 852                   NaN                NaN                         6.0
# 888                   NaN                3.0                         6.0
# 895                   2.0                NaN                         3.0
#
#      tech_self_score.Python  tech_self_score.C++  tech_self_score.Ruby  \
# 59                      NaN                  NaN                   5.0
# 154                     6.0                  NaN                   NaN
# 211                     NaN                  NaN                   1.0
# 354                     7.0                  NaN                   2.0
# 466                     NaN                  2.0                   4.0
# 700                     NaN                  NaN                   NaN
# 776                     3.0                  NaN                   NaN
# 831                     NaN                  NaN                   4.0
# 852                     NaN                  3.0                   NaN
# 888                     NaN                  NaN                   NaN
# 895                     NaN                  NaN                   NaN
#
#      tech_self_score.SPSS  tech_self_score.PHP
# 59                    NaN                  NaN
# 154                   NaN                  NaN
# 211                   NaN                  NaN
# 354                   NaN                  NaN
# 466                   3.0                  NaN
# 700                   4.0                  NaN
# 776                   1.0                  NaN
# 831                   4.0                  NaN
# 852                   NaN                  NaN
# 888                   NaN                  NaN
# 895                   NaN                  NaN

# %%
# Remove duplicates
df = df.drop_duplicates()
df.head(3)
# Out:
#                 name        date                                  strengths  \
# 0  Stillmann Castano  22/08/2019                               ['Charisma']
# 1    Hilary Willmore  01/08/2019  ['Patient', 'Curious', 'Problem Solving']
# 2      Efrem Whipple  22/08/2019    ['Courteous', 'Independent', 'Patient']
#
#                                    weaknesses self_development geo_flex  \
# 0  ['Distracted', 'Impulsive', 'Introverted']              Yes      Yes
# 1    ['Overbearing', 'Chatty', 'Indifferent']               No      Yes
# 2     ['Introverted', 'Impulsive', 'Anxious']              Yes      Yes
#
#   financial_support_self result course_interest  tech_self_score.C#  \
# 0                    Yes   Pass        Business                 6.0
# 1                    Yes   Fail            Data                 4.0
# 2                    Yes   Pass        Business                 NaN
#
#    tech_self_score.Java  tech_self_score.R  tech_self_score.JavaScript  \
# 0                   5.0                2.0                         2.0
# 1                   2.0                NaN                         NaN
# 2                   NaN                NaN                         NaN
#
#    tech_self_score.Python  tech_self_score.C++  tech_self_score.Ruby  \
# 0                     NaN                  NaN                   NaN
# 1                     1.0                  4.0                   NaN
# 2                     NaN                  4.0                   4.0
#
#    tech_self_score.SPSS  tech_self_score.PHP
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN

# %% [markdown]
# ### Data types

# %%
print(df.dtypes)
# Out:
# name                           object
# date                           object
# strengths                      object
# weaknesses                     object
# self_development               object
# geo_flex                       object
# financial_support_self         object
# result                         object
# course_interest                object
# tech_self_score.C#            float64
# tech_self_score.Java          float64
# tech_self_score.R             float64
# tech_self_score.JavaScript    float64
# tech_self_score.Python        float64
# tech_self_score.C++           float64
# tech_self_score.Ruby          float64
# tech_self_score.SPSS          float64
# tech_self_score.PHP           float64
# dtype: object

# %% [markdown]
# #### Dates

# %%
# Date 
# Try converting to datetime (invalid → NaT)
temp = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')

# %%
# Any rows that became NaT are invalid
invalid_rows = df[temp.isna()]
print(invalid_rows[['name', 'date']])
# Out:
#                       name         date
# 220       Balduin Culleton  13//08/2019
# 279        Saundra Fuzzens  28//08/2019
# 408           Hewet Derwin  11//07/2019
# 588         Joseito Duiged  17//07/2019
# 601        Arlette Pickles  11//07/2019
# 723           Jecho Rousel  05//07/2019
# 760      Homere Stentiford  25//07/2019
# 786      Hilliard Brockett  05//07/2019
# 808       Evangelin Gorges  11//07/2019
# 822  Gerianne Christoforou  13//07/2019
# 849           Byrom Sawday  11//07/2019
# 923          Tobe Markovic  05//12/2019
# 938          Nerti Welfair  11//12/2019

# %%
# Fix
df['date'] = df['date'].str.replace('//', '/', regex=False)

# %%
# Change to datetime
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')
temp = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')

# %%
# Check if fixed
invalid_rows = df[temp.isna()]
print(invalid_rows[['name', 'date']])
# Out:
# Empty DataFrame
# Columns: [name, date]
# Index: []

# %% [markdown]
# #### Booleans

# %%
bool_cols = ['self_development', 'geo_flex', 'financial_support_self']
for col in bool_cols:
    df[col] = df[col].map({'Yes': True, 'No': False})

# %% [markdown]
# #### Object to Category

# %%
# result as categorical
df['result'] = df['result'].astype('category')

# %%
# course_interest as categorical 
df['course_interest'] = df['course_interest'].astype('category')

# %% [markdown]
# #### Strengths and weaknesses -> CSVs

# %%
# strengths and weaknesses to lists
df['strengths'] = df['strengths'].apply(lambda x: ', '.join(x))
df['weaknesses'] = df['weaknesses'].apply(lambda x: ', '.join(x))

# %% [markdown]
# #### Rename columns

# %%
# Rename tech scores columns
df.columns = df.columns.str.replace('#', 'Sharp').str.replace('.', '_')

# %% [markdown]
# ### Check

# %%
print(df.dtypes)
# Out:
# name                                  object
# date                          datetime64[ns]
# strengths                             object
# weaknesses                            object
# self_development                        bool
# geo_flex                                bool
# financial_support_self                  bool
# result                              category
# course_interest                     category
# tech_self_score_CSharp               float64
# tech_self_score_Java                 float64
# tech_self_score_R                    float64
# tech_self_score_JavaScript           float64
# tech_self_score_Python               float64
# tech_self_score_C++                  float64
# tech_self_score_Ruby                 float64
# tech_self_score_SPSS                 float64
# tech_self_score_PHP                  float64
# dtype: object

# %% [markdown]
# #### Cleaned version

# %%
df.head(3)
# Out:
#                 name       date                          strengths  \
# 0  Stillmann Castano 2019-08-22                           Charisma
# 1    Hilary Willmore 2019-08-01  Patient, Curious, Problem Solving
# 2      Efrem Whipple 2019-08-22    Courteous, Independent, Patient
#
#                            weaknesses  self_development  geo_flex  \
# 0  Distracted, Impulsive, Introverted              True      True
# 1    Overbearing, Chatty, Indifferent             False      True
# 2     Introverted, Impulsive, Anxious              True      True
#
#    financial_support_self result course_interest  tech_self_score_CSharp  \
# 0                    True   Pass        Business                     6.0
# 1                    True   Fail            Data                     4.0
# 2                    True   Pass        Business                     NaN
#
#    tech_self_score_Java  tech_self_score_R  tech_self_score_JavaScript  \
# 0                   5.0                2.0                         2.0
# 1                   2.0                NaN                         NaN
# 2                   NaN                NaN                         NaN
#
#    tech_self_score_Python  tech_self_score_C++  tech_self_score_Ruby  \
# 0                     NaN                  NaN                   NaN
# 1                     1.0                  4.0                   NaN
# 2                     NaN                  4.0                   4.0
#
#    tech_self_score_SPSS  tech_self_score_PHP
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN

# %% [markdown]
# ### Back to csv

# %%
df.to_csv('cleaned_talent_decision_scores.csv', index=False)
